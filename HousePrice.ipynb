# %% [markdown]
# <a href="https://colab.research.google.com/github/Vey27/Applied-Data-Science/blob/main/HousePrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HousePrice

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HousePrices.csv',parse_dates=['date'],index_col=['date'])
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-05-02  313000.0       3.0        1.5         1340      7912     1.5
# 2014-05-02  440000.0       2.0        1.0          800      4850     1.0
# 2014-05-02  287200.0       3.0        3.0         1850     19966     1.0
# 2014-05-02  403000.0       3.0        2.0         1960     13100     1.0
# 2014-05-02  750000.0       3.0        2.5         2390      6550     1.0
#
#             waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-05-02           0     0          3        1340              0      1955
# 2014-05-02           0     0          4         800              0      1944
# 2014-05-02           0     0          4        1090            760      1992
# 2014-05-02           0     2          5        1650            310      1957
# 2014-05-02           0     2          4        1440            950      1955
#
# ...

# %%
plt.plot(df['price'])

# %%
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa5c5bca9e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa5c5bc9420>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa5c5bc8d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa5c5bcb1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa5c5bc8df0>],
#  'means': []}

# %%
plt.hist(df['sqft_living'])
# Out:
# (array([1.664e+03, 2.217e+03, 5.850e+02, 1.040e+02, 2.100e+01, 5.000e+00,
#         1.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([  370.,  1687.,  3004.,  4321.,  5638.,  6955.,  8272.,  9589.,
#         10906., 12223., 13540.]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('price')
plt.ylabel('sqft_living')
plt.title('Scatter Plot')
plt.scatter(x=df['price'],y=df['sqft_living'])

# %%
d = {'a':10, 'b':20,'c':13}

# %%
plt.bar(x = d.keys(), height=d.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(x = d.values(), labels = d.keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa5c64177f0>,
# ...
#  [Text(0.8192493858343352, 0.7340507092906218, 'a'),
#   Text(-1.0736834851006882, 0.23917310430322264, 'b'),
#   Text(0.6400449045093828, -0.8946186451285124, 'c')])

# %%
plt.plot(df['price'])

# %%
plt.figure(figsize=(15,10),dpi = 100)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Line Plot of Prices')
plt.legend()
plt.plot(df['price'])
plt.savefig('Prices.png')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ![p1.PNG](data:image/png;base64,...)
