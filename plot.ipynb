# %% [markdown]
# <a href="https://colab.research.google.com/github/Vey27/Applied-Data-Science/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The organizaton plans to study the sales details of
# each product across all regions and countries. This is to identify the product which has the highest sales in a particular region and up the production. This research will enable the organization to increase the
# manufacturing of that product in the paricular region.

# %% [markdown]
# ![Visual.PNG](data:image/png;base64,...)

# %%
#import numpy for generating random numbers
import numpy as np
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline

# %%
#generate random numbers (total 10)
randomNumber = np.random.rand(10)

# %%
#view
print(randomNumber)
# Out:
# [0.365171   0.96932757 0.46185608 0.82425876 0.68693757 0.4222462
#  0.38775834 0.65150933 0.40457481 0.39470551]

# %%
# Set the style of the plot
import seaborn as sns
style.use('seaborn')

# Generate a random number
randomNumber = np.random.rand()

# Plot the random number
plt.plot([randomNumber], 'g', label='line one', linewidth=2)

# Set the x-axis label
plt.xlabel('Range')

# Set the y-axis label
plt.ylabel('Numbers')

# Set the title of the plot
plt.title('First Plot')

# Display the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-18-084f672828f7>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn')
